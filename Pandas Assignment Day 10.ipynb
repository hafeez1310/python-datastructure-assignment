# %% [markdown]
# # <center>Pandas Assignment</center>

# %% [markdown]
# Import pandas and numpy with their aliases

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Create a variable a = pd.Series([ 100, 200, 300, 400])

# %%
# a = 
a = pd.Series([100,200,300,400])

# %% [markdown]
# Print a, and data type

# %%
print(a)
print(type(a))
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64
# <class 'pandas.Series'>

# %% [markdown]
# Using indexing access the element 300 from the series a.

# %%
a[2]
# Out:
# np.int64(300)

# %% [markdown]
# What are the values of index for series a?

# %%
a.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# Change the index to  ['c', 'a', 'b', 'd']

# %%
a.index = ['a', 'b', 'c','d']
a
# Out:
# a    100
# b    200
# c    300
# d    400
# dtype: int64

# %% [markdown]
# Access the value in the series with index 'd'

# %%
a['d']
# Out:
# np.int64(400)

# %% [markdown]
# Sort the values wrt to the index and print it

# %%
a_sorted = a.sort_index()
print(a_sorted)
# Out:
# a    100
# b    200
# c    300
# d    400
# dtype: int64

# %% [markdown]
# Create a new Pandas Series b having index as 'e', 'f', and 'g' and value 800,450,100 and print it

# %%
b = pd.Series([800,450,100],index=['e','f','g'])
b
# Out:
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Append b series at the end of a series

# %%
# a =
a = pd.concat([a,b])

# %%
#print a again after appending b into it

print(a)
# Out:
# a    100
# b    200
# c    300
# d    400
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Sort the values in descending order of a and print the index of the sorted series

# %%
# a = 
a = a.sort_values(ascending=False)

# %%
print(a.index)
# Out:
# Index(['e', 'f', 'd', 'c', 'b', 'a', 'g'], dtype='str')

# %% [markdown]
# ## Pandas DataFrame

# %% [markdown]
# ### Part 1

# %% [markdown]
# Create a pandas dataframe df from the series 'a' that we used in the last section, print the dataframe

# %%
# df = 
df = pd.DataFrame(a)

# %%
df
# Out:
#      0
# e  800
# f  450
# d  400
# c  300
# b  200
# a  100
# g  100

# %% [markdown]
# What is the shape of the datafarme <br>
# (also, what does it imply?)

# %%
df.shape
# Out:
# (7, 1)

# %% [markdown]
# Hey! remember shape (7,1) implies dataframe has 7 rows and 1 column.

# %% [markdown]
# What is the index of the dataframe, is it same as the series 'a'

# %%
# yep its same as the series.
df.index
# Out:
# Index(['e', 'f', 'd', 'c', 'b', 'a', 'g'], dtype='str')

# %% [markdown]
# print the head and tail of the dataframe. <br>
# Additional - (what does head and tali represent?)

# %%
# head() --> head will return first five row the data
# tail() --> tail will return last five row the data
df.head()
# Out:
#      0
# e  800
# f  450
# d  400
# c  300
# b  200

# %%
df.tail()
# Out:
#      0
# d  400
# c  300
# b  200
# a  100
# g  100

# %% [markdown]
# Rename the column of the dataframe as 'points'

# %%
df.columns = ['points']

# %% [markdown]
# Create another Series 'fruits', which contains random names of fruits from ['orange','mango','apple']. The series should contain 7 elements, randomly selected from ['orange','mango','apple']

# %%
#Create fruits array

fruits_choice = pd.Series(['Orange', 'Mango', 'Apple'])
fruits_array = np.random.choice(fruits_choice, 7)
fruits_array
# Out:
# array(['Orange', 'Apple', 'Mango', 'Orange', 'Mango', 'Apple', 'Mango'],
#       dtype=object)

# %%
#Create series fruits out of fruits array

fruits = pd.Series(fruits_array)
fruits
# Out:
# 0    Orange
# 1     Apple
# 2     Mango
# 3    Orange
# 4     Mango
# 5     Apple
# 6     Mango
# dtype: str

# %% [markdown]
# Change the index of fruits to the index of dataframe df

# %%
fruits.index = df.index
fruits
# Out:
# e    Orange
# f     Apple
# d     Mango
# c    Orange
# b     Mango
# a     Apple
# g     Mango
# dtype: str

# %% [markdown]
# Add this fruits series as a new column to the dataframe df with its column name as 'fruits'
# <br>print the head of the dataframe to verify

# %%
df['fruits'] = fruits

# %%
df.head()
# Out:
#    points  fruits
# e     800  Orange
# f     450   Apple
# d     400   Mango
# c     300  Orange
# b     200   Mango

# %% [markdown]
# ## Pandas Concatenation

# %% [markdown]
# Create a dataframe  d1 where the cols are  ‘city’ : [‘Chandigarh’, ‘Delhi’, ‘Kanpur’, ‘Chennai’, ‘Manali’ ] and ‘Temperature’ : [15, 22, 20, 26,-2]

# %%
d1 = pd.DataFrame({
    'city':['Chandigarh', 'Delhi', 'Kanpur', 'Chennai', 'Manali'],
    'Temperature': [15,22,20,26,-2]
})

# %% [markdown]
# Print(d1)

# %%
print(d1)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# What is the shape of d1.

# %%
d1.shape
# Out:
# (5, 2)

# %% [markdown]
# Set city = d1['city']

# %%
city = d1['city']

# %% [markdown]
# print city <br>
# What is the type of city.

# %%
print(city)
print(type(city))
# Out:
# 0    Chandigarh
# 1         Delhi
# 2        Kanpur
# 3       Chennai
# 4        Manali
# Name: city, dtype: str
# <class 'pandas.Series'>

# %% [markdown]
# Create another datafeame 'd2' where the columns are <br>
# 'city' - ['Bengalaru','Coimbatore','Srirangam','Pondicherry'] <br>
# 'Temperature' - [24,35,36,39]

# %%
d2 = pd.DataFrame({
    'city':['Bengaluru', 'Coimbatore', 'Srirangam', 'Pondicheery'],
    'Temperature' : [24,35,36,39]
})

# %% [markdown]
# print the shape of this dataframe

# %%
d2.shape
# Out:
# (4, 2)

# %% [markdown]
# merge the two dataframes together, save it in a new dataframe named 'd3'

# %%
# d3 = 

d3 = pd.concat([d1,d2])
d3
# Out:
#           city  Temperature
# 0   Chandigarh           15
# 1        Delhi           22
# 2       Kanpur           20
# 3      Chennai           26
# 4       Manali           -2
# 0    Bengaluru           24
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicheery           39

# %% [markdown]
# Select the part of the dataframe such that it contains cities wherer temp is less then or equal to 20 <br>
# How many cities are there?

# %%
d3[d3['Temperature'] <= 20]
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 2      Kanpur           20
# 4      Manali           -2

# %% [markdown]
# Select the part of the dataframe such that it contains the cities where tempearature greater than or equal to 35

# %%
d3[d3['Temperature'] >= 35]
# Out:
#           city  Temperature
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicheery           39

# %% [markdown]
# ## Applying functions to columns and creating new columns

# %% [markdown]
# We need to create another column in d3, which contains  a boolean value for each city to indicate whether it's a union territory or not.
# - HINT: Chandigarh, Pondicherry and Delhi are only 3 union territories here.

# %%
# write function here
def is_ut(x):
    return x in ['chandigarh', 'Pondicheery', 'Delhi']

d3['is_ut'] = d3['city'].apply(is_ut)
# def is_ut(x):
    
#     # write code below
    
# d3['is_ut'] =

# %%
print(d3)
# Out:
#           city  Temperature  is_ut
# 0   Chandigarh           15  False
# 1        Delhi           22   True
# 2       Kanpur           20  False
# 3      Chennai           26  False
# 4       Manali           -2  False
# 0    Bengaluru           24  False
# 1   Coimbatore           35  False
# 2    Srirangam           36  False
# 3  Pondicheery           39   True

# %% [markdown]
# The temperatures mentioned in ‘Temperature’ column are mentioned in Celsius, we need another column which contains the same in Fahrenheit.

# %% [markdown]
# HINT -
# - Define a function c_to_f which takes input temp in celsius and returns a value with temperature in Fahrenheit.
# - To check: c_to_f(10) should return 50.

# %%
# write function here

def c_to_f(temp_c):
    return (temp_c * 9/5) +32

# %%
# check function c_to_f(10)

c_to_f(10)
# Out:
# 50.0

# %%
# apply function c_to_f to d3 to create a column 'temp_farenhiet'

d3['temp_farenhiet'] =  d3['Temperature'].apply(c_to_f)
d3
# Out:
#           city  Temperature  is_ut  temp_farenhiet
# 0   Chandigarh           15  False            59.0
# 1        Delhi           22   True            71.6
# 2       Kanpur           20  False            68.0
# 3      Chennai           26  False            78.8
# 4       Manali           -2  False            28.4
# 0    Bengaluru           24  False            75.2
# 1   Coimbatore           35  False            95.0
# 2    Srirangam           36  False            96.8
# 3  Pondicheery           39   True           102.2

# %% [markdown]
# ## Indexing and selecting rows in DataFrame

# %% [markdown]
# Select subset of the dataframe d1 such that it contains the cities which are union territories.

# %%
d1[d1['city'].isin(['Chandigarh', 'Pondicherry', 'Delhi'])]
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22

# %% [markdown]
# Select a subset of the dataframe d1 such that it contains the cities which only have temperature above 90 Farenhiet.

# %%
d1[d1['Temperature'].apply(c_to_f) > 90]
# Out:
# Empty DataFrame
# Columns: [city, Temperature]
# Index: []

# %% [markdown]
# Select only the first three rows of the dataframe d1.

# %%
df.head(3)
# Out:
#    points  fruits
# e     800  Orange
# f     450   Apple
# d     400   Mango

# %% [markdown]
# Select all the rows and last two columns in the dataframe.

# %%
d1.iloc[:,:2]
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# ## Groupby

# %%
# Create a dataframe using dictionary of your choice

data = pd.DataFrame({
    'city' : ['Telangana', 'Bombay', 'Kashmir', 'Kerala', 'Hyderabad'],
    'Category':['UT', 'UT', 'State', 'State', 'UT'],
    'Sales': [10,20,15,30,5]
})

data
# Out:
#         city Category  Sales
# 0  Telangana       UT     10
# 1     Bombay       UT     20
# 2    Kashmir    State     15
# 3     Kerala    State     30
# 4  Hyderabad       UT      5

# %%
# Use Groupby of single column with aggregate sum()

data.groupby('city')['Sales'].sum()
# Out:
# city
# Bombay       20
# Hyderabad     5
# Kashmir      15
# Kerala       30
# Telangana    10
# Name: Sales, dtype: int64

# %%
# Use Groupby of single column with aggregate count()

data.groupby('Category')['Sales'].count()
# Out:
# Category
# State    2
# UT       3
# Name: Sales, dtype: int64

# %%
# Use Groupby of single column with aggregate min() and max()

data.groupby('city')['Sales'].agg(['min', 'max'])
# Out:
#            min  max
# city
# Bombay      20   20
# Hyderabad    5    5
# Kashmir     15   15
# Kerala      30   30
# Telangana   10   10

# %%
# Use Groupby of any 2 columns with aggregate mean()

data.groupby(['city', 'Category'])['Sales'].mean()
# Out:
# city       Category
# Bombay     UT          20.0
# Hyderabad  UT           5.0
# Kashmir    State       15.0
# Kerala     State       30.0
# Telangana  UT          10.0
# Name: Sales, dtype: float64

# %%
# Use Groupby of any 2 columns with aggregate min() and max()

data.groupby(['city', 'Category'])['Sales'].agg(['min', 'max'])
# Out:
#                     min  max
# city      Category
# Bombay    UT         20   20
# Hyderabad UT          5    5
# Kashmir   State      15   15
# Kerala    State      30   30
# Telangana UT         10   10

# %% [markdown]
# ## Data Range

# %% [markdown]
# Create a pandas daterange where starting date is 1st of January,2020 and end date is 1st of April 2021, store it in a new variable named 'a'

# %%
a = pd.date_range(start='2020-01-01', end='2021-04-01')

# %% [markdown]
# print a

# %%
print(a)
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26',
#                '2021-03-27', '2021-03-28', '2021-03-29', '2021-03-30',
#                '2021-03-31', '2021-04-01'],
#               dtype='datetime64[us]', length=457, freq='D')

# %% [markdown]
# What is the len of a?

# %%
print(len(a))
# Out:
# 457

# %% [markdown]
# What is the type of a?

# %%
print(type(a))
# Out:
# <class 'pandas.DatetimeIndex'>
